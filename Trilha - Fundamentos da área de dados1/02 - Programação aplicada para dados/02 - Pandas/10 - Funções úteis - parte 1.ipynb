# %% [markdown]
# ![Growdev](https://www.growdev.com.br/assets/images/logo_growdev.png)

# %% [markdown]
# # Tópicos da Aula de Hoje

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/2560px-Pandas_logo.svg.png" width="500" height="200" />
#
# - Funções Úteis
#   - `isnull`
#   - `dropnull`
#   - `duplicated`
#   - `drop_duplicated`
#   - `unique`
#   - `nunique`
#   - `replace`

# %% [markdown]
# **Bora pra aula?**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Funções Úteis

# %%
df_pokemons = pd.read_csv('pokemon_data.csv')
df_pokemons
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]

# %%
df_pokemons.drop(['#'], axis=1, inplace=True)
df_pokemons
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass  Poison  45      49       49       65
# 1                  Ivysaur    Grass  Poison  60      62       63       80
# 2                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  50     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# 1         80     60           1      False
# 2        100     80           1      False
# 3        120     80           1      False
# 4         50     65           1      False
# ..       ...    ...         ...        ...
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True
#
# [800 rows x 11 columns]

# %%
df_pokemons.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison  45      49       49       65
# 1                Ivysaur  Grass  Poison  60      62       63       80
# 2               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ## `isnull`

# %% [markdown]
# Campos vazios podem surgir em nossos dados corriqueiramente. Eles têm diversas origens e, dependendo dessa origem, receberão diferentes tratamentos. De início vamos aprender a observar essas ocorrências e o tratamento mais simples para eles: Exclusão (nem sempre a mais indicada).

# %%
df_pokemons.isnull()
# Out:
#       Name  Type 1  Type 2     HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0    False   False   False  False   False    False    False    False  False
# 1    False   False   False  False   False    False    False    False  False
# 2    False   False   False  False   False    False    False    False  False
# 3    False   False   False  False   False    False    False    False  False
# 4    False   False    True  False   False    False    False    False  False
# ..     ...     ...     ...    ...     ...      ...      ...      ...    ...
# 795  False   False   False  False   False    False    False    False  False
# 796  False   False   False  False   False    False    False    False  False
# 797  False   False   False  False   False    False    False    False  False
# 798  False   False   False  False   False    False    False    False  False
# 799  False   False   False  False   False    False    False    False  False
#
#      Generation  Legendary
# 0         False      False
# 1         False      False
# 2         False      False
# 3         False      False
# 4         False      False
# ..          ...        ...
# 795       False      False
# 796       False      False
# 797       False      False
# 798       False      False
# 799       False      False
#
# [800 rows x 11 columns]

# %%
int(False)
# Out:
# 0

# %%
int(True)
# Out:
# 1

# %%
df_pokemons.isnull().sum()
# Out:
# Name            0
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
# .transpose()
# .T

# %%
df_pokemons.isna().sum()
# Out:
# Name            0
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
# Contagem de NULL 
# Ela vai pegar valores None e NaN
#df_pokemons.isnull().sum()
df_pokemons.isna().sum()
# Out:
# Name            0
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df_pokemons.loc[df_pokemons['HP']>100]
# Out:
#                  Name  Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 44         Jigglypuff  Normal   Fairy  115      45       20       45       25
# 45         Wigglytuff  Normal   Fairy  140      70       45       85       50
# 96                Muk  Poison     NaN  105     105       75       65      100
# 120            Rhydon  Ground    Rock  105     130      120       45       45
# 121           Chansey  Normal     NaN  250       5        5       35      105
# ..                ...     ...     ...  ...     ...      ...      ...      ...
# 753        Aromatisse   Fairy     NaN  101      72       72       99       89
# 769           Aurorus    Rock     Ice  123      77       72       99       92
# 792           Xerneas   Fairy     NaN  126     131       95      131       98
# 793           Yveltal    Dark  Flying  126     131       95      131       98
# 794  Zygarde50% Forme  Dragon  Ground  108     100      121       81       95
#
#      Speed  Generation  Legendary
# 44      20           1      False
# 45      45           1      False
# 96      50           1      False
# 120     40           1      False
# 121     50           1      False
# ..     ...         ...        ...
# 753     29           6      False
# 769     58           6      False
# 792     99           6       True
# 793     99           6       True
# 794     95           6       True
#
# [67 rows x 11 columns]

# %%
df_pokemons.loc[df_pokemons['Type 2'].isnull()]
# Out:
#            Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 4    Charmander    Fire    NaN   39      52       43       60       50     65
# 5    Charmeleon    Fire    NaN   58      64       58       80       65     80
# 9      Squirtle   Water    NaN   44      48       65       50       64     43
# 10    Wartortle   Water    NaN   59      63       80       65       80     58
# 11    Blastoise   Water    NaN   79      83      100       85      105     78
# ..          ...     ...    ...  ...     ...      ...      ...      ...    ...
# 775     Sliggoo  Dragon    NaN   68      75       53       83      113     60
# 776      Goodra  Dragon    NaN   90     100       70      110      150     80
# 788    Bergmite     Ice    NaN   55      69       85       32       35     28
# 789     Avalugg     Ice    NaN   95     117      184       44       46     28
# 792     Xerneas   Fairy    NaN  126     131       95      131       98     99
#
#      Generation  Legendary
# 4             1      False
# 5             1      False
# 9             1      False
# 10            1      False
# 11            1      False
# ..          ...        ...
# 775           6      False
# 776           6      False
# 788           6      False
# 789           6      False
# 792           6       True
#
# [386 rows x 11 columns]

# %%
nulos = df_pokemons.loc[df_pokemons['Type 2'].isnull()]
nulos
# Out:
#            Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 4    Charmander    Fire    NaN   39      52       43       60       50     65
# 5    Charmeleon    Fire    NaN   58      64       58       80       65     80
# 9      Squirtle   Water    NaN   44      48       65       50       64     43
# 10    Wartortle   Water    NaN   59      63       80       65       80     58
# 11    Blastoise   Water    NaN   79      83      100       85      105     78
# ..          ...     ...    ...  ...     ...      ...      ...      ...    ...
# 775     Sliggoo  Dragon    NaN   68      75       53       83      113     60
# 776      Goodra  Dragon    NaN   90     100       70      110      150     80
# 788    Bergmite     Ice    NaN   55      69       85       32       35     28
# 789     Avalugg     Ice    NaN   95     117      184       44       46     28
# 792     Xerneas   Fairy    NaN  126     131       95      131       98     99
#
#      Generation  Legendary
# 4             1      False
# 5             1      False
# 9             1      False
# 10            1      False
# 11            1      False
# ..          ...        ...
# 775           6      False
# 776           6      False
# 788           6      False
# 789           6      False
# 792           6       True
#
# [386 rows x 11 columns]

# %%
nulos.shape
# Out:
# (386, 11)

# %% [markdown]
# ## `dropnull`

# %%
df_pokemons.shape
# Out:
# (800, 11)

# %%
# Dropando NULL
# Dropna tem uma série de argumentos, sugiro olhar a documentação
df_pokemons_sem_na = df_pokemons.dropna()
df_pokemons_sem_na
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass  Poison  45      49       49       65
# 1                  Ivysaur    Grass  Poison  60      62       63       80
# 2                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 6                Charizard     Fire  Flying  78      84       78      109
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  50     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# 1         80     60           1      False
# 2        100     80           1      False
# 3        120     80           1      False
# 6         85    100           1      False
# ..       ...    ...         ...        ...
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True
#
# [414 rows x 11 columns]

# %%
df_pokemons
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass  Poison  45      49       49       65
# 1                  Ivysaur    Grass  Poison  60      62       63       80
# 2                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  50     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# 1         80     60           1      False
# 2        100     80           1      False
# 3        120     80           1      False
# 4         50     65           1      False
# ..       ...    ...         ...        ...
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True
#
# [800 rows x 11 columns]

# %% [markdown]
# <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html">Clique Aqui</a> para saber mais sobre o dropna()

# %% [markdown]
# ## `duplicated`

# %%
df_pokemons.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Length: 800, dtype: bool

# %%
df_pokemons.duplicated().sum()
# Out:
# 0

# %%
df_pokemons['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
df_pokemons['Type 1'].nunique()
# Out:
# 18

# %%
df_pokemons.duplicated(subset=['Type 1']).sum()
# Out:
# 782

# %%
# Checar se uma linha é duplicada
df_pokemons.duplicated().sum()
#df_pokemons.duplicated(subset = ['Type 1']).sum()
# Out:
# 0

# %% [markdown]
# ## `drop_duplicated`

# %%
# Dropar linhas duplicadas, mantendo a primeira ocorrência
df_pokemons.drop_duplicates(subset=['Type 1'], keep=False)
# Out:
# Empty DataFrame
# Columns: [Name, Type 1, Type 2, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
df_pokemons
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass  Poison  45      49       49       65
# 1                  Ivysaur    Grass  Poison  60      62       63       80
# 2                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  50     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# 1         80     60           1      False
# 2        100     80           1      False
# 3        120     80           1      False
# 4         50     65           1      False
# ..       ...    ...         ...        ...
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True
#
# [800 rows x 11 columns]

# %% [markdown]
# ## `unique` e `nunique`

# %%
# Checar os elementos únicos de uma coluna (funciona muito bem quando a coluna é qualitiva/categórica)
df_pokemons['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df_pokemons['Type 2'].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
df_pokemons['Type 1'].nunique()
# Out:
# 18

# %%
df_pokemons['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
df_pokemons.loc[df_pokemons['Type 1']=='Flying']
# Out:
#                         Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 702  TornadusIncarnate Forme  Flying     NaN  79     115       70      125
# 703    TornadusTherian Forme  Flying     NaN  79     100       80      110
# 790                   Noibat  Flying  Dragon  40      30       35       45
# 791                  Noivern  Flying  Dragon  85      70       80       97
#
#      Sp. Def  Speed  Generation  Legendary
# 702       80    111           5       True
# 703       90    121           5       True
# 790       40     55           6      False
# 791       80    123           6      False

# %% [markdown]
# ## `replace`

# %%
df_pokemons.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison  45      49       49       65
# 1                Ivysaur  Grass  Poison  60      62       63       80
# 2               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# Replace (substituir um valor por outro), equivale ao localizar e substituir do excel
df_pokemons.replace({True:'Verdadeiro', False:'Falso'})
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass  Poison  45      49       49       65
# 1                  Ivysaur    Grass  Poison  60      62       63       80
# 2                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  50     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation   Legendary
# 0         65     45           1       Falso
# 1         80     60           1       Falso
# 2        100     80           1       Falso
# 3        120     80           1       Falso
# 4         50     65           1       Falso
# ..       ...    ...         ...         ...
# 795      150     50           6  Verdadeiro
# 796      110    110           6  Verdadeiro
# 797      130     70           6  Verdadeiro
# 798      130     80           6  Verdadeiro
# 799       90     70           6  Verdadeiro
#
# [800 rows x 11 columns]

# %%
df_pokemons.replace({'Grass': 'GROWDEV'})
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur  GROWDEV  Poison  45      49       49       65
# 1                  Ivysaur  GROWDEV  Poison  60      62       63       80
# 2                 Venusaur  GROWDEV  Poison  80      82       83      100
# 3    VenusaurMega Venusaur  GROWDEV  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  50     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# 1         80     60           1      False
# 2        100     80           1      False
# 3        120     80           1      False
# 4         50     65           1      False
# ..       ...    ...         ...        ...
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True
#
# [800 rows x 11 columns]

# %%
df_pokemons.replace({'Grass': 'GROWDEV'})['Type 1']
# Out:
# 0      GROWDEV
# 1      GROWDEV
# 2      GROWDEV
# 3      GROWDEV
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
df_pokemons['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
df_pokemons.replace({'Grass': 'GROWDEV'})['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# GROWDEV      70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
df_pokemons
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass  Poison  45      49       49       65
# 1                  Ivysaur    Grass  Poison  60      62       63       80
# 2                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  50     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# 1         80     60           1      False
# 2        100     80           1      False
# 3        120     80           1      False
# 4         50     65           1      False
# ..       ...    ...         ...        ...
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True
#
# [800 rows x 11 columns]
