# %% [markdown]
# ![Growdev](https://www.growdev.com.br/assets/images/logo_growdev.png)

# %% [markdown]
# # Tópicos da Aula de Hoje

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/2560px-Pandas_logo.svg.png" width="500" height="200" />
#
# - Limpeza de Dados:
#   - Por que fazer ?
#   - Investigação e Definição de Tipos
#   - Investigação de inconsistências

# %% [markdown]
# Bora pra aula?

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Limpeza de Dados

# %% [markdown]
# ## Investigação e Definição de Tipos

# %% [markdown]
# A primeira coisa que você deve identificar é o tipo das colunas com as quais você vai lidar. Geralmente lidamos com centenas de colunas e mapear isso é trabalhoso. E esse processo vai depender vai depender do conhecimento de negócio.

# %%
# Carregando os dados
nyc_sales = pd.read_csv('nyc-rolling-sales_twentieth.csv')

# %%
nyc_sales.head()
# Out:
#    Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ...  \
# 0    6                                  C2            153 AVENUE B  ...
# 1   26                                  C7   234 EAST 4TH   STREET  ...
# 2   39                                  C7   197 EAST 3RD   STREET  ...
# 3   21                                  C4     154 EAST 7TH STREET  ...
# 4   55                                  C2  301 EAST 10TH   STREET  ...
#
#   RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                 5                 0            5              1633
# 1                28                 3           31              4616
# 2                16                 1           17              2212
# 3                10                 0           10              2272
# 4                 6                 0            6              2369
#
#    GROSS SQUARE FEET YEAR BUILT TAX CLASS AT TIME OF SALE  \
# 0               6440       1900                         2
# 1              18690       1900                         2
# 2               7803       1900                         2
# 3               6794       1913                         2
# 4               4615       1900                         2
#
#    BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE
# 0                              C2     6625000  2017-07-19 00:00:00
# 1                              C7         -    2016-12-14 00:00:00
# 2                              C7         -    2016-12-09 00:00:00
# 3                              C4     3936272  2016-09-23 00:00:00
# 4                              C2     8000000  2016-11-17 00:00:00
#
# [5 rows x 22 columns]

# %% [markdown]
# A primeira coisa que observamos é a coluna ```Unnamed: 0```. Devemos removê-la, já que nem nome ela possui. Essa coluna surge geralmente devido a gravação do índice do dataframe como coluna do csv. Se quisermos evitar que um índice de dataframe seja salvo após nossa análise, passamos o parâmetro ```index=False``` para o método ```.to_csv()```.

# %%
nyc_sales.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
nyc_sales.head()
# Out:
#    BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0                   2A    392    6                                  C2
# 1                    2    399   26                                  C7
# 2                    2    399   39                                  C7
# 3                   2B    402   21                                  C4
# 4                   2A    404   55                                  C2
#
#                   ADDRESS APARTMENT NUMBER  ...  RESIDENTIAL UNITS  \
# 0            153 AVENUE B                   ...                  5
# 1   234 EAST 4TH   STREET                   ...                 28
# 2   197 EAST 3RD   STREET                   ...                 16
# 3     154 EAST 7TH STREET                   ...                 10
# 4  301 EAST 10TH   STREET                   ...                  6
#
#    COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET GROSS SQUARE FEET  \
# 0                 0            5              1633              6440
# 1                 3           31              4616             18690
# 2                 1           17              2212              7803
# 3                 0           10              2272              6794
# 4                 0            6              2369              4615
#
#   YEAR BUILT  TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  \
# 0       1900                          2                              C2
# 1       1900                          2                              C7
# 2       1900                          2                              C7
# 3       1913                          2                              C4
# 4       1900                          2                              C2
#
#   SALE PRICE            SALE DATE
# 0    6625000  2017-07-19 00:00:00
# 1        -    2016-12-14 00:00:00
# 2        -    2016-12-09 00:00:00
# 3    3936272  2016-09-23 00:00:00
# 4    8000000  2016-11-17 00:00:00
#
# [5 rows x 21 columns]

# %% [markdown]
# No Link abaixo podemos ver um pouco da descrição dos dados.<br>
# <a href="https://www.kaggle.com/new-york-city/nyc-property-sales"> Descrição dos Dados</a>

# %%
nyc_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16909 entries, 0 to 16908
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         16909 non-null  int64
#  1   NEIGHBORHOOD                    16909 non-null  object
#  2   BUILDING CLASS CATEGORY         16909 non-null  object
#  3   TAX CLASS AT PRESENT            16909 non-null  object
#  4   BLOCK                           16909 non-null  int64
#  5   LOT                             16909 non-null  int64
#  6   EASE-MENT                       16909 non-null  object
#  7   BUILDING CLASS AT PRESENT       16909 non-null  object
#  8   ADDRESS                         16909 non-null  object
#  9   APARTMENT NUMBER                16909 non-null  object
#  10  ZIP CODE                        16909 non-null  int64
#  11  RESIDENTIAL UNITS               16909 non-null  int64
#  12  COMMERCIAL UNITS                16909 non-null  int64
#  13  TOTAL UNITS                     16909 non-null  int64
#  14  LAND SQUARE FEET                16909 non-null  object
#  15  GROSS SQUARE FEET               16909 non-null  object
#  16  YEAR BUILT                      16909 non-null  int64
#  17  TAX CLASS AT TIME OF SALE       16909 non-null  int64
#  18  BUILDING CLASS AT TIME OF SALE  16909 non-null  object
#  19  SALE PRICE                      16909 non-null  object
#  20  SALE DATE                       16909 non-null  object
# dtypes: int64(9), object(12)
# memory usage: 2.7+ MB

# %%
nyc_sales.dtypes
# Out:
# BOROUGH                            int64
# NEIGHBORHOOD                      object
# BUILDING CLASS CATEGORY           object
# TAX CLASS AT PRESENT              object
# BLOCK                              int64
# LOT                                int64
# EASE-MENT                         object
# BUILDING CLASS AT PRESENT         object
# ADDRESS                           object
# APARTMENT NUMBER                  object
# ZIP CODE                           int64
# RESIDENTIAL UNITS                  int64
# COMMERCIAL UNITS                   int64
# TOTAL UNITS                        int64
# LAND SQUARE FEET                  object
# GROSS SQUARE FEET                 object
# YEAR BUILT                         int64
# TAX CLASS AT TIME OF SALE          int64
# BUILDING CLASS AT TIME OF SALE    object
# SALE PRICE                        object
# SALE DATE                         object
# dtype: object

# %% [markdown]
# Algumas variáveis que são do tipo numérico estão representadas como ```object```:
# * ```SALE PRICE```
# * ```GROSS SQUARE FEET```
# * ```LAND SQUARE FEET```
# * ```APARTMENT NUMBER```

# %% [markdown]
# Da mesma maneira temos variáveis categóricas que estão como ```int64```:
# * ```BOROUGH```
# * ```BLOCK```
# * ```LOT```
# * ```TAX CLASS AT TIME OF SALE```

# %% [markdown]
# Inclusive, a própria descrição das variáveis nos revela que podemos utilizar BLOCK da seguinte maneira: Manhattan (1), Bronx (2), Brooklyn (3), Queens (4), and Staten Island (5).

# %% [markdown]
# Vamos tentar algumas conversões? Para isso iremos tentar as conversões através do método ```.astype()```

# %%
nyc_sales.columns
# Out:
# Index(['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', 'ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE'],
#       dtype='object')

# %%
nyc_sales['SALE PRICE']
# Out:
# 0        6625000
# 1            -
# 2            -
# 3        3936272
# 4        8000000
#           ...
# 16904        -
# 16905     712500
# 16906     740000
# 16907    1800000
# 16908        -
# Name: SALE PRICE, Length: 16909, dtype: object

# %%
# object to float
nyc_sales['SALE PRICE'] = nyc_sales['SALE PRICE'].astype('float32')
# errors = ignore garantem que se tiver algum missing, mesmo assim será convertido
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 # object to float
# ----> 2 nyc_sales['SALE PRICE'] = nyc_sales['SALE PRICE'].astype('float32')
#       3 # errors = ignore garantem que se tiver algum missing, mesmo assim será convertido
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/internals/managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/internals/managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/internals/blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or arr.dtype == object or dtype == object:
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: ' -  '

# %%
nyc_sales.loc[nyc_sales['SALE PRICE']==' -  ']
# Out:
#        BOROUGH             NEIGHBORHOOD  \
# 1            1            ALPHABET CITY
# 2            1            ALPHABET CITY
# 5            1            ALPHABET CITY
# 7            1            ALPHABET CITY
# 8            1            ALPHABET CITY
# ...        ...                      ...
# 16871        1  UPPER WEST SIDE (79-96)
# 16874        1  UPPER WEST SIDE (79-96)
# 16875        1  UPPER WEST SIDE (79-96)
# 16904        1  UPPER WEST SIDE (79-96)
# 16908        1  UPPER WEST SIDE (79-96)
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 1      07 RENTALS - WALKUP APARTMENTS                                 2
# 2      07 RENTALS - WALKUP APARTMENTS                                 2
# 5      07 RENTALS - WALKUP APARTMENTS                                 2
# 7      07 RENTALS - WALKUP APARTMENTS                                 2
# 8      08 RENTALS - ELEVATOR APARTMENTS                               2
# ...                                            ...                  ...
# 16871  10 COOPS - ELEVATOR APARTMENTS                                 2
# 16874  10 COOPS - ELEVATOR APARTMENTS                                 2
# 16875  10 COOPS - ELEVATOR APARTMENTS                                 2
# 16904  10 COOPS - ELEVATOR APARTMENTS                                 2
# 16908  10 COOPS - ELEVATOR APARTMENTS                                 2
#
#        BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 1        399   26                                  C7
# 2        399   39                                  C7
# 5        405   16                                  C4
# 7        407   18                                  C7
# 8        379   34                                  D5
# ...      ...  ...       ...                       ...
# 16871   1230   61                                  D4
# 16874   1231    1                                  D4
# 16875   1231    1                                  D4
# 16904   1237   29                                  D4
# 16908   1237   29                                  D4
#
#                         ADDRESS APARTMENT NUMBER  ...  RESIDENTIAL UNITS  \
# 1         234 EAST 4TH   STREET                   ...                 28
# 2         197 EAST 3RD   STREET                   ...                 16
# 5        516 EAST 12TH   STREET                   ...                 20
# 7        520 EAST 14TH   STREET                   ...                 44
# 8                  141 AVENUE D                   ...                 15
# ...                         ...              ...  ...                ...
# 16871   470 WEST END AVENUE, 3F                   ...                  0
# 16874   490 WEST END AVENUE, 7A                   ...                  0
# 16875   490 WEST END AVENUE, 7B                   ...                  0
# 16904  201 WEST 89TH STREET, 9A                   ...                  0
# 16908     201 W 89TH STREET, 8E                   ...                  0
#
#        COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET GROSS SQUARE FEET  \
# 1                     3           31              4616             18690
# 2                     1           17              2212              7803
# 5                     0           20              2581              9730
# 7                     2           46              5163             21007
# 8                     0           15              1534              9198
# ...                 ...          ...               ...               ...
# 16871                 0            0               -                 -
# 16874                 0            0               -                 -
# 16875                 0            0               -                 -
# 16904                 0            0               -                 -
# 16908                 0            0               -                 -
#
#       YEAR BUILT  TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  \
# 1           1900                          2                              C7
# 2           1900                          2                              C7
# 5           1900                          2                              C4
# 7           1900                          2                              C7
# 8           1920                          2                              D5
# ...          ...                        ...                             ...
# 16871       1928                          2                              D4
# 16874       1913                          2                              D4
# 16875       1913                          2                              D4
# 16904       1925                          2                              D4
# 16908       1925                          2                              D4
#
#       SALE PRICE            SALE DATE
# 1            -    2016-12-14 00:00:00
# 2            -    2016-12-09 00:00:00
# 5            -    2017-07-20 00:00:00
# 7            -    2017-07-20 00:00:00
# 8            -    2017-06-20 00:00:00
# ...          ...                  ...
# 16871        -    2017-08-01 00:00:00
# 16874        -    2017-03-16 00:00:00
# 16875        -    2017-03-16 00:00:00
# 16904        -    2017-02-08 00:00:00
# 16908        -    2017-05-04 00:00:00
#
# [3514 rows x 21 columns]

# %% [markdown]
# Não houve conversão, pois existe um ```-``` no meio das colunas. Isso é um indício de que valores faltosos são representados dessa maneira no nosso dataframe.

# %% [markdown]
# Vamos usar outro método: ```pd.to_nummeric```.

# %%
nyc_sales['SALE PRICE'] = pd.to_numeric(nyc_sales['SALE PRICE'], errors='coerce')
nyc_sales['SALE PRICE']
# Out:
# 0        6625000.0
# 1              NaN
# 2              NaN
# 3        3936272.0
# 4        8000000.0
#            ...
# 16904          NaN
# 16905     712500.0
# 16906     740000.0
# 16907    1800000.0
# 16908          NaN
# Name: SALE PRICE, Length: 16909, dtype: float64

# %%
nyc_sales
# Out:
#        BOROUGH             NEIGHBORHOOD  \
# 0            1            ALPHABET CITY
# 1            1            ALPHABET CITY
# 2            1            ALPHABET CITY
# 3            1            ALPHABET CITY
# 4            1            ALPHABET CITY
# ...        ...                      ...
# 16904        1  UPPER WEST SIDE (79-96)
# 16905        1  UPPER WEST SIDE (79-96)
# 16906        1  UPPER WEST SIDE (79-96)
# 16907        1  UPPER WEST SIDE (79-96)
# 16908        1  UPPER WEST SIDE (79-96)
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                 2
# 2      07 RENTALS - WALKUP APARTMENTS                                 2
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# ...                                            ...                  ...
# 16904  10 COOPS - ELEVATOR APARTMENTS                                 2
# 16905  10 COOPS - ELEVATOR APARTMENTS                                 2
# 16906  10 COOPS - ELEVATOR APARTMENTS                                 2
# 16907  10 COOPS - ELEVATOR APARTMENTS                                 2
# 16908  10 COOPS - ELEVATOR APARTMENTS                                 2
#
#        BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0        392    6                                  C2
# 1        399   26                                  C7
# 2        399   39                                  C7
# 3        402   21                                  C4
# 4        404   55                                  C2
# ...      ...  ...       ...                       ...
# 16904   1237   29                                  D4
# 16905   1237   29                                  D4
# 16906   1237   29                                  D4
# 16907   1237   29                                  D4
# 16908   1237   29                                  D4
#
#                          ADDRESS APARTMENT NUMBER  ...  RESIDENTIAL UNITS  \
# 0                   153 AVENUE B                   ...                  5
# 1          234 EAST 4TH   STREET                   ...                 28
# 2          197 EAST 3RD   STREET                   ...                 16
# 3            154 EAST 7TH STREET                   ...                 10
# 4         301 EAST 10TH   STREET                   ...                  6
# ...                          ...              ...  ...                ...
# 16904   201 WEST 89TH STREET, 9A                   ...                  0
# 16905  201 WEST 89TH STREET, 10C                   ...                  0
# 16906        201 WEST 89 ST, 10D                   ...                  0
# 16907   201 WEST 89TH STREET, 7G                   ...                  0
# 16908      201 W 89TH STREET, 8E                   ...                  0
#
#        COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET GROSS SQUARE FEET  \
# 0                     0            5              1633              6440
# 1                     3           31              4616             18690
# 2                     1           17              2212              7803
# 3                     0           10              2272              6794
# 4                     0            6              2369              4615
# ...                 ...          ...               ...               ...
# 16904                 0            0               -                 -
# 16905                 0            0               -                 -
# 16906                 0            0               -                 -
# 16907                 0            0               -                 -
# 16908                 0            0               -                 -
#
#       YEAR BUILT  TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  \
# 0           1900                          2                              C2
# 1           1900                          2                              C7
# 2           1900                          2                              C7
# 3           1913                          2                              C4
# 4           1900                          2                              C2
# ...          ...                        ...                             ...
# 16904       1925                          2                              D4
# 16905       1925                          2                              D4
# 16906       1925                          2                              D4
# 16907       1925                          2                              D4
# 16908       1925                          2                              D4
#
#       SALE PRICE            SALE DATE
# 0      6625000.0  2017-07-19 00:00:00
# 1            NaN  2016-12-14 00:00:00
# 2            NaN  2016-12-09 00:00:00
# 3      3936272.0  2016-09-23 00:00:00
# 4      8000000.0  2016-11-17 00:00:00
# ...          ...                  ...
# 16904        NaN  2017-02-08 00:00:00
# 16905   712500.0  2017-02-13 00:00:00
# 16906   740000.0  2017-02-13 00:00:00
# 16907  1800000.0  2017-04-27 00:00:00
# 16908        NaN  2017-05-04 00:00:00
#
# [16909 rows x 21 columns]

# %%
def to_int(value):
    numero = int(value)
    return numero

# %%
nyc_sales['GROSS SQUARE FEET']
# Out:
# 0         6440
# 1        18690
# 2         7803
# 3         6794
# 4         4615
#          ...
# 16904      -
# 16905      -
# 16906      -
# 16907      -
# 16908      -
# Name: GROSS SQUARE FEET, Length: 16909, dtype: object

# %%
# Vamos usar um for para converter as demais 
# SALE PRICE GROSS SQUARE FEET LAND SQUARE FEET    APARTMENT NUMBER
nyc_sales['GROSS SQUARE FEET'].map(to_int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 # Vamos usar um for para converter as demais
#       2 # SALE PRICE GROSS SQUARE FEET LAND SQUARE FEET    APARTMENT NUMBER
# ----> 3 nyc_sales['GROSS SQUARE FEET'].map(to_int)
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/series.py:4540, in Series.map(self, arg, na_action)
#    4460 def map(
#    4461     self,
#    4462     arg: Callable | Mapping | Series,
#    4463     na_action: Literal["ignore"] | None = None,
#    4464 ) -> Series:
#    4465     """
#    4466     Map values of Series according to an input mapping or function.
#    4467
#    (...)
#    4538     dtype: object
#    4539     """
# -> 4540     new_values = self._map_values(arg, na_action=na_action)
#    4541     return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4542         self, method="map"
#    4543     )
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2917, in pandas._libs.lib.map_infer()
#
# Cell In[14], line 2, in to_int(value)
#       1 def to_int(value):
# ----> 2     numero = int(value)
#       3     return numero
#
# ValueError: invalid literal for int() with base 10: ' -  '

# %%
for coluna in ['SALE PRICE', 'GROSS SQUARE FEET', 'LAND SQUARE FEET', 'APARTMENT NUMBER']:
    # print(coluna)
    # print(nyc_sales[coluna].head())
    # print('#'*50)
    
    nyc_sales[coluna] = pd.to_numeric(nyc_sales[coluna], errors='coerce')

# %%
nyc_sales.head()
# Out:
#    BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0                   2A    392    6                                  C2
# 1                    2    399   26                                  C7
# 2                    2    399   39                                  C7
# 3                   2B    402   21                                  C4
# 4                   2A    404   55                                  C2
#
#                   ADDRESS  APARTMENT NUMBER  ...  RESIDENTIAL UNITS  \
# 0            153 AVENUE B               NaN  ...                  5
# 1   234 EAST 4TH   STREET               NaN  ...                 28
# 2   197 EAST 3RD   STREET               NaN  ...                 16
# 3     154 EAST 7TH STREET               NaN  ...                 10
# 4  301 EAST 10TH   STREET               NaN  ...                  6
#
#    COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# 0                 0            5            1633.0             6440.0
# 1                 3           31            4616.0            18690.0
# 2                 1           17            2212.0             7803.0
# 3                 0           10            2272.0             6794.0
# 4                 0            6            2369.0             4615.0
#
#    YEAR BUILT  TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  \
# 0        1900                          2                              C2
# 1        1900                          2                              C7
# 2        1900                          2                              C7
# 3        1913                          2                              C4
# 4        1900                          2                              C2
#
#   SALE PRICE            SALE DATE
# 0  6625000.0  2017-07-19 00:00:00
# 1        NaN  2016-12-14 00:00:00
# 2        NaN  2016-12-09 00:00:00
# 3  3936272.0  2016-09-23 00:00:00
# 4  8000000.0  2016-11-17 00:00:00
#
# [5 rows x 21 columns]

# %%
nyc_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16909 entries, 0 to 16908
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         16909 non-null  int64
#  1   NEIGHBORHOOD                    16909 non-null  object
#  2   BUILDING CLASS CATEGORY         16909 non-null  object
#  3   TAX CLASS AT PRESENT            16909 non-null  object
#  4   BLOCK                           16909 non-null  int64
#  5   LOT                             16909 non-null  int64
#  6   EASE-MENT                       16909 non-null  object
#  7   BUILDING CLASS AT PRESENT       16909 non-null  object
#  8   ADDRESS                         16909 non-null  object
#  9   APARTMENT NUMBER                1156 non-null   float64
#  10  ZIP CODE                        16909 non-null  int64
#  11  RESIDENTIAL UNITS               16909 non-null  int64
#  12  COMMERCIAL UNITS                16909 non-null  int64
#  13  TOTAL UNITS                     16909 non-null  int64
#  14  LAND SQUARE FEET                1731 non-null   float64
#  15  GROSS SQUARE FEET               1621 non-null   float64
#  16  YEAR BUILT                      16909 non-null  int64
#  17  TAX CLASS AT TIME OF SALE       16909 non-null  int64
#  18  BUILDING CLASS AT TIME OF SALE  16909 non-null  object
#  19  SALE PRICE                      13395 non-null  float64
#  20  SALE DATE                       16909 non-null  object
# dtypes: float64(4), int64(9), object(8)
# memory usage: 2.7+ MB

# %% [markdown]
# Perceba que agora aparecem valores Null no nosso dataframe.

# %% [markdown]
# As variáveis categóricas que estão como inteiro iremos converter para ```object```.

# %%
for coluna in ['BLOCK', 'LOT', 'TAX CLASS AT TIME OF SALE']:
    nyc_sales[coluna] =  nyc_sales[coluna].astype('object')

# %%
nyc_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16909 entries, 0 to 16908
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         16909 non-null  int64
#  1   NEIGHBORHOOD                    16909 non-null  object
#  2   BUILDING CLASS CATEGORY         16909 non-null  object
#  3   TAX CLASS AT PRESENT            16909 non-null  object
#  4   BLOCK                           16909 non-null  object
#  5   LOT                             16909 non-null  object
#  6   EASE-MENT                       16909 non-null  object
#  7   BUILDING CLASS AT PRESENT       16909 non-null  object
#  8   ADDRESS                         16909 non-null  object
#  9   APARTMENT NUMBER                1156 non-null   float64
#  10  ZIP CODE                        16909 non-null  int64
#  11  RESIDENTIAL UNITS               16909 non-null  int64
#  12  COMMERCIAL UNITS                16909 non-null  int64
#  13  TOTAL UNITS                     16909 non-null  int64
#  14  LAND SQUARE FEET                1731 non-null   float64
#  15  GROSS SQUARE FEET               1621 non-null   float64
#  16  YEAR BUILT                      16909 non-null  int64
#  17  TAX CLASS AT TIME OF SALE       16909 non-null  object
#  18  BUILDING CLASS AT TIME OF SALE  16909 non-null  object
#  19  SALE PRICE                      13395 non-null  float64
#  20  SALE DATE                       16909 non-null  object
# dtypes: float64(4), int64(6), object(11)
# memory usage: 2.7+ MB

# %% [markdown]
# Para as variável BOROUGH, vamos seguir as recomendações da "documentação"

# %%
# Podemos usar a função map
#Manhattan (1), Bronx (2), Brooklyn (3), Queens (4), and Staten Island (5).
# Como substituir?

# %%
# %%timeit
nyc_sales['BOROUGH'].replace([1, 2, 3, 4, 5], ['Manhatan', 'Bronx', 'Brooklyn', 'Queens', 'Staten Island'])
# Out:
# 1.13 ms ± 129 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%timeit
nyc_sales['BOROUGH'].replace( {1:'Manhatan', 2:'Bronx', 3:'Brooklyn', 4:'Queens', 5:'Staten Island'})
# Out:
# 1.05 ms ± 110 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%timeit
nyc_sales['BOROUGH'].map({1:'Manhatan', 2:'Bronx', 3:'Brooklyn', 4:'Queens', 5:'Staten Island'})
# Out:
# 366 µs ± 49.6 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
def get_borough(code):
    if code==1:
        return 'Manhattan'
    elif code==2:
        return 'Bronx'
    elif code==3:
        return 'Brooklyn'
    elif code==4:
        return 'Queens'
    else:
        return 'Staten Island'

# %%
# %%timeit
nyc_sales['BOROUGH'].apply(get_borough)
# Out:
# 1.41 ms ± 102 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
nyc_sales['BOROUGH'] = nyc_sales['BOROUGH'].map({1:'Manhatan', 2:'Bronx', 3:'Brooklyn', 4:'Queens', 5:'Staten Island'})
nyc_sales
# Out:
#         BOROUGH             NEIGHBORHOOD  \
# 0      Manhatan            ALPHABET CITY
# 1      Manhatan            ALPHABET CITY
# 2      Manhatan            ALPHABET CITY
# 3      Manhatan            ALPHABET CITY
# 4      Manhatan            ALPHABET CITY
# ...         ...                      ...
# 16904  Manhatan  UPPER WEST SIDE (79-96)
# 16905  Manhatan  UPPER WEST SIDE (79-96)
# 16906  Manhatan  UPPER WEST SIDE (79-96)
# 16907  Manhatan  UPPER WEST SIDE (79-96)
# 16908  Manhatan  UPPER WEST SIDE (79-96)
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT BLOCK  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A   392
# 1      07 RENTALS - WALKUP APARTMENTS                                 2   399
# 2      07 RENTALS - WALKUP APARTMENTS                                 2   399
# 3      07 RENTALS - WALKUP APARTMENTS                                2B   402
# 4      07 RENTALS - WALKUP APARTMENTS                                2A   404
# ...                                            ...                  ...   ...
# 16904  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16905  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16906  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16907  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16908  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
#
#       LOT EASE-MENT BUILDING CLASS AT PRESENT                    ADDRESS  \
# 0       6                                  C2               153 AVENUE B
# 1      26                                  C7      234 EAST 4TH   STREET
# 2      39                                  C7      197 EAST 3RD   STREET
# 3      21                                  C4        154 EAST 7TH STREET
# 4      55                                  C2     301 EAST 10TH   STREET
# ...    ..       ...                       ...                        ...
# 16904  29                                  D4   201 WEST 89TH STREET, 9A
# 16905  29                                  D4  201 WEST 89TH STREET, 10C
# 16906  29                                  D4        201 WEST 89 ST, 10D
# 16907  29                                  D4   201 WEST 89TH STREET, 7G
# 16908  29                                  D4      201 W 89TH STREET, 8E
#
#        APARTMENT NUMBER  ...  RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# 0                   NaN  ...                  5                 0
# 1                   NaN  ...                 28                 3
# 2                   NaN  ...                 16                 1
# 3                   NaN  ...                 10                 0
# 4                   NaN  ...                  6                 0
# ...                 ...  ...                ...               ...
# 16904               NaN  ...                  0                 0
# 16905               NaN  ...                  0                 0
# 16906               NaN  ...                  0                 0
# 16907               NaN  ...                  0                 0
# 16908               NaN  ...                  0                 0
#
#        TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 0                5            1633.0             6440.0        1900
# 1               31            4616.0            18690.0        1900
# 2               17            2212.0             7803.0        1900
# 3               10            2272.0             6794.0        1913
# 4                6            2369.0             4615.0        1900
# ...            ...               ...                ...         ...
# 16904            0               NaN                NaN        1925
# 16905            0               NaN                NaN        1925
# 16906            0               NaN                NaN        1925
# 16907            0               NaN                NaN        1925
# 16908            0               NaN                NaN        1925
#
#        TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE SALE PRICE  \
# 0                              2                             C2  6625000.0
# 1                              2                             C7        NaN
# 2                              2                             C7        NaN
# 3                              2                             C4  3936272.0
# 4                              2                             C2  8000000.0
# ...                          ...                            ...        ...
# 16904                          2                             D4        NaN
# 16905                          2                             D4   712500.0
# 16906                          2                             D4   740000.0
# 16907                          2                             D4  1800000.0
# 16908                          2                             D4        NaN
#
#                  SALE DATE
# 0      2017-07-19 00:00:00
# 1      2016-12-14 00:00:00
# 2      2016-12-09 00:00:00
# 3      2016-09-23 00:00:00
# 4      2016-11-17 00:00:00
# ...                    ...
# 16904  2017-02-08 00:00:00
# 16905  2017-02-13 00:00:00
# 16906  2017-02-13 00:00:00
# 16907  2017-04-27 00:00:00
# 16908  2017-05-04 00:00:00
#
# [16909 rows x 21 columns]

# %%
nyc_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16909 entries, 0 to 16908
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         16909 non-null  object
#  1   NEIGHBORHOOD                    16909 non-null  object
#  2   BUILDING CLASS CATEGORY         16909 non-null  object
#  3   TAX CLASS AT PRESENT            16909 non-null  object
#  4   BLOCK                           16909 non-null  object
#  5   LOT                             16909 non-null  object
#  6   EASE-MENT                       16909 non-null  object
#  7   BUILDING CLASS AT PRESENT       16909 non-null  object
#  8   ADDRESS                         16909 non-null  object
#  9   APARTMENT NUMBER                1156 non-null   float64
#  10  ZIP CODE                        16909 non-null  int64
#  11  RESIDENTIAL UNITS               16909 non-null  int64
#  12  COMMERCIAL UNITS                16909 non-null  int64
#  13  TOTAL UNITS                     16909 non-null  int64
#  14  LAND SQUARE FEET                1731 non-null   float64
#  15  GROSS SQUARE FEET               1621 non-null   float64
#  16  YEAR BUILT                      16909 non-null  int64
#  17  TAX CLASS AT TIME OF SALE       16909 non-null  object
#  18  BUILDING CLASS AT TIME OF SALE  16909 non-null  object
#  19  SALE PRICE                      13395 non-null  float64
#  20  SALE DATE                       16909 non-null  object
# dtypes: float64(4), int64(5), object(12)
# memory usage: 2.7+ MB

# %%
nyc_sales
# Out:
#         BOROUGH             NEIGHBORHOOD  \
# 0      Manhatan            ALPHABET CITY
# 1      Manhatan            ALPHABET CITY
# 2      Manhatan            ALPHABET CITY
# 3      Manhatan            ALPHABET CITY
# 4      Manhatan            ALPHABET CITY
# ...         ...                      ...
# 16904  Manhatan  UPPER WEST SIDE (79-96)
# 16905  Manhatan  UPPER WEST SIDE (79-96)
# 16906  Manhatan  UPPER WEST SIDE (79-96)
# 16907  Manhatan  UPPER WEST SIDE (79-96)
# 16908  Manhatan  UPPER WEST SIDE (79-96)
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT BLOCK  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A   392
# 1      07 RENTALS - WALKUP APARTMENTS                                 2   399
# 2      07 RENTALS - WALKUP APARTMENTS                                 2   399
# 3      07 RENTALS - WALKUP APARTMENTS                                2B   402
# 4      07 RENTALS - WALKUP APARTMENTS                                2A   404
# ...                                            ...                  ...   ...
# 16904  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16905  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16906  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16907  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16908  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
#
#       LOT EASE-MENT BUILDING CLASS AT PRESENT                    ADDRESS  \
# 0       6                                  C2               153 AVENUE B
# 1      26                                  C7      234 EAST 4TH   STREET
# 2      39                                  C7      197 EAST 3RD   STREET
# 3      21                                  C4        154 EAST 7TH STREET
# 4      55                                  C2     301 EAST 10TH   STREET
# ...    ..       ...                       ...                        ...
# 16904  29                                  D4   201 WEST 89TH STREET, 9A
# 16905  29                                  D4  201 WEST 89TH STREET, 10C
# 16906  29                                  D4        201 WEST 89 ST, 10D
# 16907  29                                  D4   201 WEST 89TH STREET, 7G
# 16908  29                                  D4      201 W 89TH STREET, 8E
#
#        APARTMENT NUMBER  ...  RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# 0                   NaN  ...                  5                 0
# 1                   NaN  ...                 28                 3
# 2                   NaN  ...                 16                 1
# 3                   NaN  ...                 10                 0
# 4                   NaN  ...                  6                 0
# ...                 ...  ...                ...               ...
# 16904               NaN  ...                  0                 0
# 16905               NaN  ...                  0                 0
# 16906               NaN  ...                  0                 0
# 16907               NaN  ...                  0                 0
# 16908               NaN  ...                  0                 0
#
#        TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 0                5            1633.0             6440.0        1900
# 1               31            4616.0            18690.0        1900
# 2               17            2212.0             7803.0        1900
# 3               10            2272.0             6794.0        1913
# 4                6            2369.0             4615.0        1900
# ...            ...               ...                ...         ...
# 16904            0               NaN                NaN        1925
# 16905            0               NaN                NaN        1925
# 16906            0               NaN                NaN        1925
# 16907            0               NaN                NaN        1925
# 16908            0               NaN                NaN        1925
#
#        TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE SALE PRICE  \
# 0                              2                             C2  6625000.0
# 1                              2                             C7        NaN
# 2                              2                             C7        NaN
# 3                              2                             C4  3936272.0
# 4                              2                             C2  8000000.0
# ...                          ...                            ...        ...
# 16904                          2                             D4        NaN
# 16905                          2                             D4   712500.0
# 16906                          2                             D4   740000.0
# 16907                          2                             D4  1800000.0
# 16908                          2                             D4        NaN
#
#                  SALE DATE
# 0      2017-07-19 00:00:00
# 1      2016-12-14 00:00:00
# 2      2016-12-09 00:00:00
# 3      2016-09-23 00:00:00
# 4      2016-11-17 00:00:00
# ...                    ...
# 16904  2017-02-08 00:00:00
# 16905  2017-02-13 00:00:00
# 16906  2017-02-13 00:00:00
# 16907  2017-04-27 00:00:00
# 16908  2017-05-04 00:00:00
#
# [16909 rows x 21 columns]

# %% [markdown]
# Por fim, temos a coluna ```SALE DATE``` que é uma data, mas que está como string. Vamos convertê-la para data usando a função ```pd.to_datetime```

# %%
nyc_sales['SALE DATE'] = pd.to_datetime(nyc_sales['SALE DATE'], format='%Y-%m-%d %H:%M:%S')

# %%
nyc_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16909 entries, 0 to 16908
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         16909 non-null  object
#  1   NEIGHBORHOOD                    16909 non-null  object
#  2   BUILDING CLASS CATEGORY         16909 non-null  object
#  3   TAX CLASS AT PRESENT            16909 non-null  object
#  4   BLOCK                           16909 non-null  object
#  5   LOT                             16909 non-null  object
#  6   EASE-MENT                       16909 non-null  object
#  7   BUILDING CLASS AT PRESENT       16909 non-null  object
#  8   ADDRESS                         16909 non-null  object
#  9   APARTMENT NUMBER                1156 non-null   float64
#  10  ZIP CODE                        16909 non-null  int64
#  11  RESIDENTIAL UNITS               16909 non-null  int64
#  12  COMMERCIAL UNITS                16909 non-null  int64
#  13  TOTAL UNITS                     16909 non-null  int64
#  14  LAND SQUARE FEET                1731 non-null   float64
#  15  GROSS SQUARE FEET               1621 non-null   float64
#  16  YEAR BUILT                      16909 non-null  int64
#  17  TAX CLASS AT TIME OF SALE       16909 non-null  object
#  18  BUILDING CLASS AT TIME OF SALE  16909 non-null  object
#  19  SALE PRICE                      13395 non-null  float64
#  20  SALE DATE                       16909 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(5), object(11)
# memory usage: 2.7+ MB

# %%
nyc_sales.head()
# Out:
#     BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0  Manhatan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1  Manhatan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2  Manhatan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3  Manhatan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4  Manhatan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AT PRESENT BLOCK LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0                   2A   392   6                                  C2
# 1                    2   399  26                                  C7
# 2                    2   399  39                                  C7
# 3                   2B   402  21                                  C4
# 4                   2A   404  55                                  C2
#
#                   ADDRESS  APARTMENT NUMBER  ...  RESIDENTIAL UNITS  \
# 0            153 AVENUE B               NaN  ...                  5
# 1   234 EAST 4TH   STREET               NaN  ...                 28
# 2   197 EAST 3RD   STREET               NaN  ...                 16
# 3     154 EAST 7TH STREET               NaN  ...                 10
# 4  301 EAST 10TH   STREET               NaN  ...                  6
#
#    COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# 0                 0            5            1633.0             6440.0
# 1                 3           31            4616.0            18690.0
# 2                 1           17            2212.0             7803.0
# 3                 0           10            2272.0             6794.0
# 4                 0            6            2369.0             4615.0
#
#    YEAR BUILT  TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE  \
# 0        1900                          2                             C2
# 1        1900                          2                             C7
# 2        1900                          2                             C7
# 3        1913                          2                             C4
# 4        1900                          2                             C2
#
#   SALE PRICE  SALE DATE
# 0  6625000.0 2017-07-19
# 1        NaN 2016-12-14
# 2        NaN 2016-12-09
# 3  3936272.0 2016-09-23
# 4  8000000.0 2016-11-17
#
# [5 rows x 21 columns]

# %%
nyc_sales.iloc[0, 20]
# Out:
# Timestamp('2017-07-19 00:00:00')

# %%
pd.to_datetime('2020-03-12', format='%Y-%m-%d')
# Out:
# Timestamp('2020-03-12 00:00:00')

# %%
nyc_sales.iloc[0, 20] < pd.to_datetime('2020-03-12', format='%Y-%m-%d')
# Out:
# True

# %% [markdown]
# ### E inconsistências com valores númericos usando notação brasileira?
# Exemplo: vírgula para separar a casa decimal e ponto para milhar

# %%
df = pd.DataFrame(data=['1.000,56', '0,34', '1.000.000,00' ], columns=['Valor'])
df
# Out:
#           Valor
# 0      1.000,56
# 1          0,34
# 2  1.000.000,00

# %%
df.dtypes
# Out:
# Valor    object
# dtype: object

# %% [markdown]
# ```python
# pd.read_csv(CAMINHO) -> DataFrame
# pd.read_excel(CAMINHO) -> DataFrame
#
# DataFrame.to_csv(CAMINHO) -> CSV
# DataFrame.to_excel(CAMINHO) -> Excel
# ```

# %%
df.to_csv('teste.csv', index=False)

# %%
df = pd.read_csv('teste.csv')
df
# Out:
#           Valor
# 0      1.000,56
# 1          0,34
# 2  1.000.000,00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Valor   3 non-null      object
# dtypes: object(1)
# memory usage: 152.0+ bytes

# %%
# %%timeit
df = pd.read_csv('teste.csv', thousands='.', decimal=',')
df
# Out:
# 342 µs ± 21.5 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Valor   3 non-null      float64
# dtypes: float64(1)
# memory usage: 152.0 bytes

# %%
# %%timeit
df = pd.read_csv('teste.csv')
df['Valor'] = df['Valor'].str.replace('.', '').str.replace(',', '.')
df['Valor'] = pd.to_numeric(df['Valor'], errors='coerce')
df
# Out:
# 600 µs ± 108 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Investigação de Inconsistências

# %% [markdown]
# * Datas fora do range
# * Valores zerados de feet² ou preço de venda
# * Valores negativos de preço ou feet²

# %%
# Checando se há datas maiores que hoje
(nyc_sales['SALE DATE'] > '2020-03-12').sum()
# Out:
# 0

# %%
# Checando se há SALE PRICE <= 0
(nyc_sales['SALE PRICE'] <= 0).sum()
# Out:
# 0

# %%
# Checando as outras colunas
for coluna in ['SALE PRICE', 'LAND SQUARE FEET', 'GROSS SQUARE FEET']:
    
    if (nyc_sales[coluna] <= 0).sum() > 0:
        print(f'{coluna} com registros inconsistentes')
    else:
        print(f'{coluna} OK')
# Out:
# SALE PRICE OK
# LAND SQUARE FEET OK
# GROSS SQUARE FEET OK
